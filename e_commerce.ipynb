# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
df = pd.read_csv('ecommerce_bigdata.csv')

# %%
df.head()
# Out:
#   TransactionID       Date    Region     ProductCategory CustomerType  Sales  \
# 0        TX0001  6/16/2026   Eastern         Electronics    Wholesale   4924
# 1        TX0002  2/12/2026   Central         Electronics       Retail   3283
# 2        TX0003   3/1/2026  Northern                Food       Online   4049
# 3        TX0004   6/3/2026   Western  Household Products       Online   4331
# 4        TX0005  1/21/2026   Western  Household Products       Retail   3283
#
#    Profit
# 0  359.44
# 1  944.32
# 2  967.10
# 3  434.57
# 4  340.48

# %%
df.isnull().sum()
# Out:
# TransactionID      0
# Date               0
# Region             0
# ProductCategory    0
# CustomerType       0
# Sales              0
# Profit             0
# dtype: int64

# %%
df.describe()
# Out:
#              Sales       Profit
# count   200.000000   200.000000
# mean   2567.190000   456.367350
# std    1528.736925   346.853151
# min      56.000000     5.130000
# 25%    1200.500000   173.967500
# 50%    2428.000000   379.330000
# 75%    4052.000000   675.000000
# max    4998.000000  1377.040000

# %%
#Data visualization
import matplotlib.pyplot as plt

# Data visualization
plt.style.use('seaborn-v0_8-darkgrid')
fig, axes = plt.subplots(2, 2, figsize=(14, 10)) 
# Distribution of Sales:
sns.histplot(df['Sales'], bins=30, kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Distribution of Sales')   
axes[0, 0].set_xlabel('Sales')
axes[0, 0].set_ylabel('Frequency')
# Distribution of Profit:
sns.histplot(df['Profit'], bins=30, kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Distribution of Profit')
axes[0, 1].set_xlabel('Profit')
axes[0, 1].set_ylabel('Frequency')
# sales by product category (Boxplot) in the third grid
sns.boxplot(x='ProductCategory', y='Sales', data=df, ax=axes[1, 0])      
axes[1, 0].set_title('Sales by Product Category')
axes[1, 0].set_xlabel('Product Category')
axes[1, 0].set_ylabel('Sales')
fig, axes = plt.subplots(2, 2, figsize=(14, 10)) 
#Distribution of Sales:
sns.histplot(df['Sales'], bins=30, kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Distribution of Sales')   
axes[0, 0].set_xlabel('Sales')
axes[0, 0].set_ylabel('Frequency')
#Distribution of Profit:
sns.histplot(df['Profit'], bins=30, kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Distribution of Profit')
axes[0, 1].set_xlabel('Profit')
axes[0, 1].set_ylabel('Frequency')
#sales by product category (Boxplot) in the third grid
sns.boxplot(x='ProductCategory' , y= 'Sales' , data=df , ax=axes[1,0])      
axes[1, 0].set_title('Sales by Product Category')
axes[1, 0].set_xlabel('Product Category')
axes[1, 0].set_ylabel('Sales')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #Data visualization
# ----> 2 plt.style.use('seaborn-v0_8-darkgrid')
#       3 fig, axes = plt.subplots(2, 2, figsize=(14, 10))
#       4 #Distribution of Sales:
#       5 sns.histplot(df['Sales'], bins=30, kde=True, ax=axes[0, 0])
#
# NameError: name 'plt' is not defined
